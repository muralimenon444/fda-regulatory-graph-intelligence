# %%
import os

# Define the root path
repo_root = "/Workspace/Repos/muralimenon444@gmail.com/fda-regulatory-graph-intelligence"

# Standard enterprise-grade directory structure
folders = [
    "config",            # YAML/Environment variables
    "data_pipelines",    # Delta Live Tables and Auto Loader logic
    "graph_engine",      # Entity extraction and LangGraph orchestration
    "notebooks",         # Standardized notebooks for execution
    "app",               # Streamlit frontend source
    "tests"              # Unit and integration tests for graph logic
]

for folder in folders:
    path = os.path.join(repo_root, folder)
    try:
        os.makedirs(path, exist_ok=True)
        print(f"Created: {path}")
    except Exception as e:
        print(f"Failed to create {path}: {e}")
